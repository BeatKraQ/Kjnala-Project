# %%
import pandas as pd
df = pd.read_csv('./통합.csv')
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 4000)

# %%
df[df['integrated_category'] == '3_b']
# Out:
#             date     item  \
# 82    2024-01-19    MDS테크
# 173   2024-01-17       레몬
# 175   2024-01-16      TPC
# 191   2024-01-16      엘컴텍
# 203   2024-01-16     현우산업
# 214   2024-01-16    삼진엘앤디
# 253   2024-01-15     와이어블
# 282   2024-01-12     유유제약
# 334   2024-01-11    대한광통신
# 408   2024-01-09      휴니드
# 451   2024-01-09     알서포트
# 470   2024-01-08     삼성제약
# 502   2024-01-05       레몬
# 515   2024-01-05     나무기술
# 516   2024-01-05       상보
# 535   2024-01-05     세종공업
# 539   2024-01-05       레몬
# 541   2024-01-05  비플라이소프트
# 544   2024-01-05     한컴위드
# 605   2024-01-03      이엠넷
# 671   2023-12-28    CJ씨푸드
# 691   2023-12-27     나무기술
# 700   2023-12-27   티피씨글로벌
# 739   2023-12-22    NHN벅스
# 810   2023-12-21     대동스틸
# 818   2023-12-21   한국전자인증
# 865   2023-12-19    CMG제약
# 884   2023-12-19      손오공
# 909   2023-12-18     줌인터넷
# 916   2023-12-18     대한해운
# 965   2023-12-15     신화콘텍
# 975   2023-12-14     인디에프
# 1088  2023-12-12     푸드나무
# 1092  2023-12-12     YBM넷
# ...
